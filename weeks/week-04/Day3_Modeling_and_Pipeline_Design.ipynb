# %% [markdown]
# # Day 3 — Modeling & Pipeline Design
# This notebook introduces the first end-to-end training pipeline for the phase 1 capstone project.

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %%
numeric_features = ['feature_a', 'feature_b']
categorical_features = ['category_a']

preprocessor = ColumnTransformer([
    ('num', StandardScaler(), numeric_features),
    ('cat', OneHotEncoder(handle_unknown='ignore', sparse_output=False), categorical_features),
])

pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('model', LinearRegression()),
])

pipeline

# %% [markdown]
# ## Model design notes
# - Keep preprocessing and model steps together.
# - Use a linear baseline before considering a more complex model.
# - Document why you chose each feature transformation.
