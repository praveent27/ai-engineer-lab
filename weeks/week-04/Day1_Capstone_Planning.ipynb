# %% [markdown]
# # Day 1 — Capstone Planning
# This notebook maps the end-to-end workflow for Week 4. We define the problem, inspect the dataset, and set the project structure before any modeling begins.

# %%
import pandas as pd
import numpy as np

# Example dataset path placeholder
data_path = 'data/capstone_dataset.csv'

print('Capstone planning notebook loaded')

# %% [markdown]
# ## Project checklist
# - Define the objective and target variable
# - Identify feature categories and expected preprocessing
# - Choose evaluation metrics and validation strategy
# - Create a reproducible folder structure

# %%
project_plan = {
    'problem': 'Regression or classification based on dataset target',
    'dataset': 'data/capstone_dataset.csv',
    'validation': 'train_test_split or cross_val_score',
    'metric': 'RMSE for regression / F1 for classification',
    'deliverable': 'Saved pipeline + inference wrapper'
}
project_plan
